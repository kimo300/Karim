# %%
import pandas as pd

# %%
PATH = './data/athlete_events.csv'

# %%
data = pd.read_csv(PATH)

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df1 = data[(data['Year'] == 2006) & (data['Weight'] > 100)]

# %%
df1[:1]
# Out:
#         ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 8102  4476  Patrick R. Antaki   M  41.0   185.0   127.0  Lebanon  LIB
#
#             Games  Year  Season    City     Sport                    Event  \
# 8102  2006 Winter  2006  Winter  Torino  Skeleton  Skeleton Men's Skeleton
#
#      Medal
# 8102   NaN

# %%
data[data['Name'] == 'John Aalberg']['Year'].nunique()
# Out:
# 2

# %%
data[(data['Team'] == 'Switzerland') & (data['Year'] == 2008) & (data['Medal'] == 'Gold')]
# Out:
#             ID                Name Sex   Age  Height  Weight         Team  \
# 34646    17857   Fabian Cancellara   M  27.0   186.0    81.0  Switzerland
# 67290    34396       Roger Federer   M  26.0   185.0    80.0  Switzerland
# 257672  129042  Stanislas Wawrinka   M  23.0   183.0    79.0  Switzerland
#
#         NOC        Games  Year  Season     City    Sport  \
# 34646   SUI  2008 Summer  2008  Summer  Beijing  Cycling
# 67290   SUI  2008 Summer  2008  Summer  Beijing   Tennis
# 257672  SUI  2008 Summer  2008  Summer  Beijing   Tennis
#
#                                       Event Medal
# 34646   Cycling Men's Individual Time Trial  Gold
# 67290                  Tennis Men's Doubles  Gold
# 257672                 Tennis Men's Doubles  Gold

# %%
data[(data['Team'] == 'Italy') & (data['Year'] == 2016) & (data['Medal'])].describe()
# Out:
#                   ID        Age      Height      Weight    Year
# count      70.000000  70.000000   70.000000   70.000000    70.0
# mean    53947.271429  27.328571  182.371429   79.642857  2016.0
# std     40416.233185   5.266028   12.385325   14.327470     0.0
# min        62.000000  19.000000  160.000000   50.000000  2016.0
# 25%     20307.000000  23.000000  172.250000   70.000000  2016.0
# 50%     38480.000000  27.000000  182.000000   79.500000  2016.0
# 75%     95112.250000  30.000000  191.000000   92.750000  2016.0
# max    134145.000000  46.000000  208.000000  102.000000  2016.0

# %%
data[(data['Season'] == 'Winter') & (data['City'] == 'Squaw Valley')]
# Out:
#             ID                                       Name Sex   Age  Height  \
# 83          24                           Nils Egil Aaness   M  24.0     NaN
# 84          24                           Nils Egil Aaness   M  24.0     NaN
# 113         40                            Roald Edgar Aas   M  31.0     NaN
# 114         40                            Roald Edgar Aas   M  31.0     NaN
# 115         40                            Roald Edgar Aas   M  31.0     NaN
# 1307       735               Benjamin Maxwell "Ben" Acton   M  32.0     NaN
# 2071      1150                           Sven Ingvar Agge   M  34.0     NaN
# 2856      1586                           Shikashi Akazawa   M  25.0   180.0
# 2909      1621             Charles Arthur "Charlie" Akers   M  20.0   177.0
# 3938      2275                     Toimi Johannes Alatalo   M  30.0   174.0
# 3939      2275                     Toimi Johannes Alatalo   M  30.0   174.0
# ...

# %%
df2 = data[(data['Sex'] == 'M') & (data['Year'] == 2012)]

# %%
df3 = df2[df2['Sport'] == 'Basketball']

# %%
df3.shape[0]
# Out:
# 144

# %%
(df3.shape[0] / df2.shape[0])
# Out:
# 0.020267417311752287

# %%
df3.nunique()
# Out:
# ID        144
# Name      144
# Sex         1
# Age        21
# Height     33
# Weight     43
# Team       12
# NOC        12
# Games       1
# Year        1
# Season      1
# City        1
# Sport       1
# Event       1
# Medal       3
# dtype: int64

# %%
df2.nunique()
# Out:
# ID        5863
# Name      5858
# Sex          1
# Age         46
# Height      69
# Weight     115
# Team       233
# NOC        203
# Games        1
# Year         1
# Season       1
# City         1
# Sport       30
# Event      170
# Medal        3
# dtype: int64

# %%
144 / 5863 *100
# Out:
# 2.4560805048609926

# %%
data[(data['Year'] == 2008) & (data['Age'] >= 15) & (data['Age'] < 26)].nunique()
# Out:
# ID        5664
# Name      5660
# Sex          2
# Age         11
# Height      78
# Weight     119
# Team       236
# NOC        202
# Games        1
# Year         1
# Season       1
# City         1
# Sport       34
# Event      302
# Medal        3
# dtype: int64

# %%
data[(data['Year'] == 2008) & (data['Age'] >= 25) & (data['Age'] < 36)].nunique()
# Out:
# ID        5544
# Name      5538
# Sex          2
# Age         11
# Height      73
# Weight     118
# Team       243
# NOC        184
# Games        1
# Year         1
# Season       1
# City         1
# Sport       34
# Event      302
# Medal        3
# dtype: int64

# %%
data[(data['Year'] == 2008) & (data['Age'] >= 35) & (data['Age'] < 46)].nunique()
# Out:
# ID        648
# Name      648
# Sex         2
# Age        11
# Height     51
# Weight     71
# Team      129
# NOC       109
# Games       1
# Year        1
# Season      1
# City        1
# Sport      31
# Event     174
# Medal       3
# dtype: int64

# %%
data[(data['Year'] == 2008) & (data['Age'] >= 45) & (data['Age'] < 56)].nunique()
# Out:
# ID        78
# Name      78
# Sex        2
# Age       11
# Height    31
# Weight    42
# Team      49
# NOC       40
# Games      1
# Year       1
# Season     1
# City       1
# Sport      9
# Event     33
# Medal      3
# dtype: int64

# %%
data[data['Year'] == 2002].nunique()
# Out:
# ID        2399
# Name      2397
# Sex          2
# Age         31
# Height      52
# Weight      78
# Team       114
# NOC         77
# Games        1
# Year         1
# Season       1
# City         1
# Sport       15
# Event       78
# Medal        3
# dtype: int64

# %%
data[data['Year'] == 2002]['Sport].nunique()
# Out:
#   File "<ipython-input-226-4558664bac63>", line 1
#     data[data['Year'] == 2002]['Sport]'.nunique()
#                                                  ^
# SyntaxError: unexpected EOF while parsing
